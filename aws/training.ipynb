# %%
import sagemaker

# %%
# S3 prefix
prefix = 'lstm-nn'
# Creating sagemmaker session
sagemaker_session = sagemaker.Session()

# Get a SageMaker-compatible role used by this Notebook Instance.
role = 'ieavilov_localcomp'

# %%
# Uploading data to default S3 bucket
train_input = sagemaker_session.upload_data('data/', key_prefix="{}/train".format(prefix))

# %%
train_input
# Out:
# 's3://sagemaker-us-east-1-340325371232/lstm-nn/train'

# %%
train_input = 's3://sagemaker-us-east-1-340325371232/lstm-nn/train'

# %%
# Past copied link here. We will use this image to train model
image = '340325371232.dkr.ecr.us-east-1.amazonaws.com/lstm-nn:latest'

# %%
# Create an estimator
# image - link to image with your model on ECR
# role - role used by this notebook (check beginning of notebook)
# 1 - number of machines to run this code on
# ml.m4.xlarge - machine to train your model on
# output_path - link to s3 bucker where you want to save data generated by model (check output of train_input/test_input)
# sagemaker_session - current sagemaker session
clf = sagemaker.estimator.Estimator(image,
                                    role, 
                                    1, 
                                    'ml.g4dn.xlarge',
                                    output_path="s3://sagemaker-us-east-1-340325371232/lstm-nn/model",
                                    sagemaker_session = sagemaker_session)

# %%
# Fit estimator
# 'train' - name of first data channel
# 'test' - name of second data channel
clf.fit({'train' : train_input})
# Out:
# ---------------------------------------------------------------------------
# ResourceLimitExceeded                     Traceback (most recent call last)
# <ipython-input-8-9b19a9fc8231> in <module>
#       2 # 'train' - name of first data channel
#       3 # 'test' - name of second data channel
# ----> 4 clf.fit({'train' : train_input})
#
# ~\anaconda3\lib\site-packages\sagemaker\estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     530         self._prepare_for_training(job_name=job_name)
#     531
# --> 532         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#     533         self.jobs.append(self.latest_training_job)
#     534         if wait:
#
# ~\anaconda3\lib\site-packages\sagemaker\estimator.py in start_new(cls, estimator, inputs, experiment_config)
#    1081         """
#    1082         train_args = cls._get_train_args(estimator, inputs, experiment_config)
# -> 1083         estimator.sagemaker_session.train(**train_args)
#    1084
#    1085         return cls(estimator.sagemaker_session, estimator._current_job_name)
#
# ~\anaconda3\lib\site-packages\sagemaker\session.py in train(self, input_mode, input_config, role, job_name, output_config, resource_config, vpc_config, hyperparameters, stop_condition, tags, metric_definitions, enable_network_isolation, image_uri, algorithm_arn, encrypt_inter_container_traffic, use_spot_instances, checkpoint_s3_uri, checkpoint_local_path, experiment_config, debugger_rule_configs, debugger_hook_config, tensorboard_output_config, enable_sagemaker_metrics)
#     541         LOGGER.info("Creating training-job with name: %s", job_name)
#     542         LOGGER.debug("train request: %s", json.dumps(train_request, indent=4))
# --> 543         self.sagemaker_client.create_training_job(**train_request)
#     544
#     545     def _get_train_request(  # noqa: C901
#
# ~\anaconda3\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~\anaconda3\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateTrainingJob operation: The account-level service limit 'ml.g4dn.xlarge for training job usage' is 0 Instances, with current utilization of 0 Instances and a request delta of 1 Instances. Please contact AWS support to request an increase for this limit.
